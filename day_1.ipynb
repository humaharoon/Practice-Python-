# %% [markdown]
# # Variables
# Variables are used to store data in a program.They act as containers for values that can be changed or manipulated during the execution of a program.
# ## Syntax:
# variable_name = value
# ### Example:
# age = 18
# name = "Ayaan"
# * (Here 'age' ia a variable holding a numeric value , and 'name' is a variable holding text)
#
# ### Practical code Explanation:
# * In the code below, there are two variables.
# * We use the = sign (Assignment Operator) to store the value -2 and "john david" into these variables.
# * These variables are act as containers that hold our data so we can use it later in the print function.

# %%
# i store student name in std_n variable.
std_n =  "john david" 

#storing student roll number in variable 'student_roll_number
student_roll_number = -2 


print(std_n)
print(student_roll_number)
# Out:
# john david
# -2

# %% [markdown]
# ### Rules of variable naming
#
# 1: variable must be started with a letter or underscore.
#
# 2: spaces are not allowed in variables.
#
# 3: variables in python are case sensitive.
#
#
# ### forexample

# %%
student_marks=48

# %%
student marks=48 #spaces are not allowed
# Out:
#   Cell In[3], line 1
#     student marks=48
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Datatypes
#  #### 1. Integer :
# An Integer (int) is a fundamental data type in python that is used to represent whole numbers.It includes all positive and negative numbers including zero, but it does not contain any decimal or fractional parts.

# %%
# Example of integer 
student_roll_number = 2
student_age = 20

# %% [markdown]
# #### 2. float :
# A float (floating-point number) is a data type in Python used to represent numbers that have decimal point.

# %%
# Example of float
student_gpa = 3.5

# %% [markdown]
# #### 3. string :
#  A string (str) is a data type in python used to represent text. It is a sequence of characters wrapped inside quotes.
# **Two ways to create a string :**
# * ***Single-line String :***  Created using double quotes (" ") or single quotes(' ').
# * ***Multi-line string:*** Created using triple quotes(""" """). This is used when the text spans across multiple lines.

# %%
#string 
# Example of single line string 
student_name = "Ali raza"

# %%
# Example of multiline string 
ali_intro = """kjdlfkjdlkfj
kldjflsdjf
kldjflsdjf
jlkdsjflsdjf
ldjflsdkjf
"""

# %% [markdown]
# # BOOLEAN
# A **Boolean** (bool) is a data type that represents one of two values:**True or False**. It is commonly used for logical operations and checking conditions (like yes/no or on/off).

# %%
#TRUE or FALSE
is_student_passed = True 
is_student_failed = False

# %% [markdown]
# ### input function
#
# input()function allows the users to enter information which is then stored in variable.
#
# #### forexample

# %%
#input function 
name = input("Enter you name : ")

# %% [markdown]
# ### output function
#
# an output function is used to display information to the user.
#
# #### forexample

# %%
#output function 
print(name)
# Out:
# zia ul islam

# %% [markdown]
# ### print function
#
# print function is used to display output on the screen.
#
# #### forexample

# %%
print("hellow world")
# Out:
# hellow world

# %% [markdown]
# ## type casting
# - convert one datatype to another datatype
#
# ### format string
#
# a format string is a string that inserts variable values inside text.

# %%
#input function 
rollnbr = int(input("Enter your roll number : "))
print("-"*33)
#datatype 
print(type(rollnbr))
#string convert integar 
#format string 
print("my roll nbr is ", rollnbr)
print(f"my roll nbr is {rollnbr}")
# Out:
# ---------------------------------
# <class 'int'>
# my roll nbr is  2
# my roll nbr is 2

# %% [markdown]
# ### sum of two numbers

# %%
# add two numbers 
a = int(input("enter number a ")) # 2
b = int(input("enter b ")) # 3

# %%
sum = a + b # 2+3 = 5
print(sum)
# Out:
# 5

# %% [markdown]
# ### multiple variable assign
#
# it is a way to give values to multiply variables at the same time in one line.
#
# #### forexample

# %%
x,y,z = 1,2,3
print(x) # output is 1
print(y) # output is 2
print(z) # output is 3
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### single variable assign
#
# assigning a value to one variable at a time

# %%
x = 1 
y = 2 
z = 3 
print(x)
print(y)
print(z)
a=10
b=4
# Out:
# 1
# 2
# 3
# 2
# 3
